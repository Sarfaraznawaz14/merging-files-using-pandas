# %%
import pandas as pd
import os
import glob

# merging the files
joined_files = os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset", "d1p*M.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)

df_append_d1p00M = pd.DataFrame()
#append all files together
for file in joined_list:
            df_temp = pd.read_csv(file)
            df_append_d1p00M = df_append_d1p00M.append(df_temp, ignore_index=True)

df_append_d1p00M
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_append_d1p00M
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
joined_files
# Out:
# 'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p*M.clipboard'

# %%
joined_list
# Out:
# []

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sarfaraz'

# %%
os.chdir("D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset")

# %%
os.getcwd()
# Out:
# 'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset'

# %%
len(os.listdir())
# Out:
# 61

# %%
import pandas as pd
import os
import glob

# merging the files
for i in range(len(os.listdir())):
    
    joined_files = os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset", "d1p*M.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)

df_append_d1p00M = pd.DataFrame()
#append all files together
for file in joined_list:
            df_temp = pd.read_csv(file)
            df_append_d1p00M = df_append_d1p00M.append(df_temp, ignore_index=True)

df_append_d1p00M
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# merging the files
joined_files_1to9M = []
for i in range(1,10):
    
    joined_files_1to9M.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset", "d1p0"+str(i)+"M"))
joined_files_10M = []
for i in range(10,len(os.listdir())):
    joined_files_10M.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset", "d1p"+str(i)+"M"))
    
joined_files_M = joined_files_1to9M + joined_files_10M

# merging the files
joined_files_1to9F = []
for i in range(1,10):
    
    joined_files_1to9F.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset", "d1p0"+str(i)+"F"))
joined_files_10F = []
for i in range(10,len(os.listdir())):
    joined_files_10F.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset", "d1p"+str(i)+"F"))
    
joined_files_F = joined_files_1to9F + joined_files_10F

# %%
joined_files_M
# Out:
# ['D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p01M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p02M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p03M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p04M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p05M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p06M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p07M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p08M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p09M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p10M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p11M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p12M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p13M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p14M',
# ...

# %%
joined_files_F
# Out:
# ['D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p01F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p02F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p03F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p04F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p05F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p06F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p07F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p08F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p09F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p10F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p11F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p12F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p13F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p14F',
# ...

# %%
joined_files_sorted = []
for i in range(len(os.listdir())-1):
    if joined_files_M[i] == original_files[i]:
        joined_files_sorted.append(joined_files_M[i])
for j in range(len(os.listdir())-1):
    if joined_files_F[j] == original_files[j]:
        joined_files_sorted.append(joined_files_F[j])

# %%
joined_files_sorted
# Out:
# ['D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p01M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p02M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p03M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p04M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p05M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p06M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p07M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p36M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p37M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p38M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p39M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p40M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p41M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p42M',
# ...

# %%
os.listdir()[0]
# Out:
# 'd1p01M'

# %%
df = pd.read_csv("D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p60F")

# %%
df
# Out:
#            0   0.24858   1.0542  -0.24174  1  -45.5  4.4286  920.25  4
# 0      0.025  0.342380  1.18050 -0.116310  1  -45.0  4.6234  921.75  4
# 1      0.250  0.060972  1.07710 -0.036490  1  -44.5  5.8445  921.75  4
# 2      0.300  0.131320  1.05420 -0.082102  1  -49.5  6.2249  923.25  4
# 3      1.500  0.471360  0.90487  0.020525  2  -56.0  1.2533  921.25  4
# 4      2.250  0.471360  0.90487  0.020525  2  -57.5  5.8920  924.25  4
# ..       ...       ...      ...       ... ..    ...     ...     ... ..
# 718  485.000  0.330660  0.95081 -0.230340  1  -57.0  6.2188  921.75  1
# 719  485.080  0.330660  0.95081 -0.230340  3  -58.0  0.8805  921.75  1
# 720  485.500  0.330660  0.95081 -0.230340  1  -60.5  5.0054  924.75  1
# 721  488.250  0.119600  0.82449  0.009122  4  -56.0  4.9087  925.75  4
# 722  488.750  0.072698  1.31830  0.009122  4  -56.5  1.0370  922.75  4
#
# [723 rows x 9 columns]

# %%
if joined_files_M[0] == "D:\\Home Work\\Datasets_Healthy_Older_People\S1_Dataset" + os.listdir()[0]:
        print(joined_files_M[0])
# Out:
# D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset\d1p01M

# %%
original_files = []
for i in range(len(os.listdir())-1):
    original_files.append("D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\" + os.listdir()[i])

# %%
original_files
# Out:
# ['D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p01M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p02M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p03M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p04M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p05M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p06M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p07M',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p08F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p09F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p10F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p11F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p12F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p13F',
#  'D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p14F',
# ...

# %%
# Out:
# ('D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p34F',)

# %%
# Out:
# ('D:\\Home\\Work\\Datasets_Healthy_Older_People\\S1_Dataset\\d1p36F',)

# %%
os.chdir("D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset")

# merging the files
joined_files_1to9M = []
for i in range(1,10):
    
    joined_files_1to9M.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset", "d1p0"+str(i)+"M"))
joined_files_10M = []
for i in range(10,len(os.listdir())):
    joined_files_10M.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset", "d1p"+str(i)+"M"))
    
joined_files_M = joined_files_1to9M + joined_files_10M

# merging the files
joined_files_1to9F = []
for i in range(1,10):
    
    joined_files_1to9F.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset", "d1p0"+str(i)+"F"))
joined_files_10F = []
for i in range(10,len(os.listdir())):
    joined_files_10F.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S1_Dataset", "d1p"+str(i)+"F"))
    
joined_files_F = joined_files_1to9F + joined_files_10F

original_files = []
for i in range(len(os.listdir())-1):
    original_files.append("D:\\Home Work\\Datasets_Healthy_Older_People\\S1_Dataset\\" + os.listdir()[i])

joined_files_sorted = []
for i in range(len(os.listdir())-1):
    if joined_files_M[i] == original_files[i]:
        joined_files_sorted.append(joined_files_M[i])
for j in range(len(os.listdir())-1):
    if joined_files_F[j] == original_files[j]:
        joined_files_sorted.append(joined_files_F[j])
        
joined_files_sorted



df_append_d1p = pd.DataFrame()
#append all files together
for file in joined_files_sorted:
            df_temp = pd.read_csv(file,header=None)
            df_append_d1p = df_append_d1p.append(df_temp, ignore_index=True)

df_append_d1p
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_12804\1400795202.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_d1p = df_append_d1p.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_12804\1400795202.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_d1p = df_append_d1p.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_12804\1400795202.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_d1p = df_append_d1p.append(df_temp, ignore_index=True)
# ...

# %%
df_append_d1p.columns = ["Time(s)", "Acceleration_for_frontal_axis","Acceleration_for_vertical_axis",
             "Acceleration_for_lateral_axis", " antenna_reading", "RSSI", "phase",
              "frequency", "label_of_activity"]

# %%
df_append_d1p
# Out:
#        Time(s)  Acceleration_for_frontal_axis  Acceleration_for_vertical_axis  \
# 0         0.00                       0.272030                         1.00820
# 1         0.50                       0.272030                         1.00820
# 2         1.50                       0.447910                         0.91636
# 3         1.75                       0.447910                         0.91636
# 4         2.50                       0.342380                         0.96229
# ...        ...                            ...                             ...
# 52477   485.00                       0.330660                         0.95081
# 52478   485.08                       0.330660                         0.95081
# 52479   485.50                       0.330660                         0.95081
# 52480   488.25                       0.119600                         0.82449
# 52481   488.75                       0.072698                         1.31830
#
# ...

# %%
df_append_d1p["setup"] = "s1"

# %%
df_append_d1p
# Out:
#        Time(s)  Acceleration_for_frontal_axis  Acceleration_for_vertical_axis  \
# 0         0.00                       0.272030                         1.00820
# 1         0.50                       0.272030                         1.00820
# 2         1.50                       0.447910                         0.91636
# 3         1.75                       0.447910                         0.91636
# 4         2.50                       0.342380                         0.96229
# ...        ...                            ...                             ...
# 52477   485.00                       0.330660                         0.95081
# 52478   485.08                       0.330660                         0.95081
# 52479   485.50                       0.330660                         0.95081
# 52480   488.25                       0.119600                         0.82449
# 52481   488.75                       0.072698                         1.31830
#
# ...

# %%
os.chdir("D:\Home Work\Datasets_Healthy_Older_People\S2_Dataset")

# %%
os.getcwd()
# Out:
# 'D:\\Home Work\\Datasets_Healthy_Older_People\\S2_Dataset'

# %%
os.chdir("D:\Home Work\Datasets_Healthy_Older_People\S2_Dataset")

# merging the files
joined_files_1to9M = []
for i in range(1,10):
    
    joined_files_1to9M.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S2_Dataset", "d2p0"+str(i)+"M"))
joined_files_10M = []
for i in range(10,len(os.listdir())):
    joined_files_10M.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S2_Dataset", "d2p"+str(i)+"M"))
    
joined_files_M = joined_files_1to9M + joined_files_10M

# merging the files
joined_files_1to9F = []
for i in range(1,10):
    
    joined_files_1to9F.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S2_Dataset", "d2p0"+str(i)+"F"))
joined_files_10F = []
for i in range(10,len(os.listdir())):
    joined_files_10F.append(os.path.join(r"D:\Home Work\Datasets_Healthy_Older_People\S2_Dataset", "d2p"+str(i)+"F"))
    
joined_files_F = joined_files_1to9F + joined_files_10F

original_files = []
for i in range(len(os.listdir())-1):
    original_files.append("D:\\Home Work\\Datasets_Healthy_Older_People\\S2_Dataset\\" + os.listdir()[i])

joined_files_sorted = []
for i in range(len(os.listdir())-1):
    if joined_files_M[i] == original_files[i]:
        joined_files_sorted.append(joined_files_M[i])
for j in range(len(os.listdir())-1):
    if joined_files_F[j] == original_files[j]:
        joined_files_sorted.append(joined_files_F[j])
        
joined_files_sorted



df_append_d2p = pd.DataFrame()
#append all files together
for file in joined_files_sorted:
            df_temp = pd.read_csv(file,header=None)
            df_append_d2p = df_append_d2p.append(df_temp, ignore_index=True)



df_append_d2p.columns = ["Time(s)", "Acceleration_for_frontal_axis","Acceleration_for_vertical_axis",
             "Acceleration_for_lateral_axis", " antenna_reading", "RSSI", "phase",
              "frequency", "label_of_activity"]
df_append_d2p["setup"] = "s2"


df_append_d2p
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_12804\686745425.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_d2p = df_append_d2p.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_12804\686745425.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_d2p = df_append_d2p.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_12804\686745425.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_d2p = df_append_d2p.append(df_temp, ignore_index=True)
# ...

# %%
final_df = df_append_d1p + df_append_d2p

# %%
final_df
# Out:
#        Time(s)  Acceleration_for_frontal_axis  Acceleration_for_vertical_axis  \
# 0         0.00                        0.40335                         2.02790
# 1         5.50                        0.40335                         2.02790
# 2         6.75                        0.88410                         1.84420
# 3         7.25                        0.81374                         1.86717
# 4         8.50                        0.80202                         1.89013
# ...        ...                            ...                             ...
# 52477      NaN                            NaN                             NaN
# 52478      NaN                            NaN                             NaN
# 52479      NaN                            NaN                             NaN
# 52480      NaN                            NaN                             NaN
# 52481      NaN                            NaN                             NaN
#
# ...

# %%
df_final = df_append_d1p.append(df_append_d2p)
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_12804\110341790.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_final = df_append_d1p.append(df_append_d2p)

# %%
df_final
# Out:
#        Time(s)  Acceleration_for_frontal_axis  Acceleration_for_vertical_axis  \
# 0         0.00                        0.27203                         1.00820
# 1         0.50                        0.27203                         1.00820
# 2         1.50                        0.44791                         0.91636
# 3         1.75                        0.44791                         0.91636
# 4         2.50                        0.34238                         0.96229
# ...        ...                            ...                             ...
# 22641   444.00                        0.90520                         0.64076
# 22642   449.00                        0.90520                         0.64076
# 22643   451.50                        0.42446                         0.91636
# 22644   451.58                        0.42446                         0.91636
# 22645   452.25                        0.58862                         0.87042
#
# ...

# %%
df_final.to_csv("summarised_dataset.csv")

# %%
pd.read_csv("summarised_dataset.csv")
# Out:
#        Unnamed: 0  Time(s)  Acceleration_for_frontal_axis  \
# 0               0     0.00                        0.27203
# 1               1     0.50                        0.27203
# 2               2     1.50                        0.44791
# 3               3     1.75                        0.44791
# 4               4     2.50                        0.34238
# ...           ...      ...                            ...
# 75123       22641   444.00                        0.90520
# 75124       22642   449.00                        0.90520
# 75125       22643   451.50                        0.42446
# 75126       22644   451.58                        0.42446
# 75127       22645   452.25                        0.58862
#
#        Acceleration_for_vertical_axis  Acceleration_for_lateral_axis  \
# 0                             1.00820                      -0.082102
# 1                             1.00820                      -0.082102
# ...

# %%
import pandas as pd
import os
import glob

# %%
os.chdir(r"C:\Users\sarfaraz\Downloads\AReM\walking")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sarfaraz\\Downloads\\AReM\\walking'

# %%
os.listdir()
# Out:
# ['dataset1.csv',
#  'dataset10.csv',
#  'dataset11.csv',
#  'dataset12.csv',
#  'dataset13.csv',
#  'dataset14.csv',
#  'dataset15.csv',
#  'dataset2.csv',
#  'dataset3.csv',
#  'dataset4.csv',
#  'dataset5.csv',
#  'dataset6.csv',
#  'dataset7.csv',
#  'dataset8.csv',
#  'dataset9.csv']

# %%
pd.read_csv("dataset1.csv",skiprows=4)
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      35.00       3.67      16.50       3.77      14.00
# 1                250      28.50       3.35      17.50       3.77      12.25
# 2                500      35.50       2.87      15.75       2.86      17.75
# 3                750      29.75      12.19      16.25       2.17      20.75
# 4               1000      27.00       2.12      16.75       0.83      24.75
# ..               ...        ...        ...        ...        ...        ...
# 475           118750      35.50       4.27      15.67       4.78      17.00
# 476           119000      30.75       2.49      18.50       4.15      18.00
# 477           119250      36.00       2.94      16.25       1.30      16.67
# 478           119500      37.40       6.15      10.25       5.31      14.60
# 479           119750      34.67       1.25      18.00       1.87       9.33
#
#      var_rss23
# 0         1.63
# 1         3.90
# ...

# %%
# importing libraries
import pandas as pd
import glob
import os
  
# merging the files
joined_files = os.path.join(r"C:\Users\sarfaraz\Downloads\AReM\walking", "dataset*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)
  
# Finally, the files are joined
df = pd.concat(pd.read_csv((str[i for i in joined_list]), skiprows=4), ignore_index=True)
print(df)

# %%
joined_list
# Out:
# []

# %%
# merging the files
joined_files = os.path.join(r"C:\Users\sarfaraz\Downloads\AReM\walking", "dataset*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)

# %%
type(joined_list)
# Out:
# list

# %%
lista = []
for i in joined_list:
    lista.append(i)

# %%
joined_list[1]
# Out:
# 'C:\\Users\\sarfaraz\\Downloads\\AReM\\walking\\dataset10.csv'

# %%
numbers = (range(1,16))
result = map([i for i in joined_list],numbers)
print(result)

# %%
[j for j in joined_list[i]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 [j for j in joined_list[i]]
#
# NameError: name 'i' is not defined

# %%
df_append = pd.DataFrame()
#append all files together
for file in joined_list:
            df_temp = pd.read_csv(file, skiprows=4)
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\1554134334.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\1554134334.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\1554134334.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\1554134334.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
# merging the files
joined_files = os.path.join(r"C:\Users\sarfaraz\Downloads\AReM\walking", "dataset*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)

df_append_walking = pd.DataFrame()
#append all files together
for file in joined_list:
            df_temp = pd.read_csv(file, skiprows=4)
            df_append_walking = df_append_walking.append(df_temp, ignore_index=True)
df_append_walking
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\3601481520.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_walking = df_append_walking.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\3601481520.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_walking = df_append_walking.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\3601481520.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_walking = df_append_walking.append(df_temp, ignore_index=True)
# ...

# %%
df_append_walking["label"] = "walking"

# %%
df_append_walking
# Out:
#       # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                   0      35.00       3.67      16.50       3.77      14.00
# 1                 250      28.50       3.35      17.50       3.77      12.25
# 2                 500      35.50       2.87      15.75       2.86      17.75
# 3                 750      29.75      12.19      16.25       2.17      20.75
# 4                1000      27.00       2.12      16.75       0.83      24.75
# ...               ...        ...        ...        ...        ...        ...
# 7195           118750      31.50       1.66      12.50       3.20      14.25
# 7196           119000      27.33       1.25      11.33       0.94      20.00
# 7197           119250      37.80       7.68      14.20       2.48      17.25
# 7198           119500      33.75       1.30      15.75       5.21      16.50
# 7199           119750      32.67       3.09      18.67       0.47      14.00
#
#       var_rss23    label
# ...

# %%
df_append_walking.to_csv("walking_merge.csv")

# %%
pd.read_csv("walking_merge.csv")
# Out:
#       Unnamed: 0  # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  \
# 0              0                0      35.00       3.67      16.50       3.77
# 1              1              250      28.50       3.35      17.50       3.77
# 2              2              500      35.50       2.87      15.75       2.86
# 3              3              750      29.75      12.19      16.25       2.17
# 4              4             1000      27.00       2.12      16.75       0.83
# ...          ...              ...        ...        ...        ...        ...
# 7195        7195           118750      31.50       1.66      12.50       3.20
# 7196        7196           119000      27.33       1.25      11.33       0.94
# 7197        7197           119250      37.80       7.68      14.20       2.48
# 7198        7198           119500      33.75       1.30      15.75       5.21
# 7199        7199           119750      32.67       3.09      18.67       0.47
#
# ...

# %%
# merging the files
joined_files = os.path.join(r"C:\Users\sarfaraz\Downloads\AReM\standing", "dataset*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)

df_append_standing = pd.DataFrame()
#append all files together
for file in joined_list:
            df_temp = pd.read_csv(file, skiprows=4)
            df_append_standing = df_append_standing.append(df_temp, ignore_index=True)
df_append_standing
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\739575137.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_standing = df_append_standing.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\739575137.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_standing = df_append_standing.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\739575137.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_standing = df_append_standing.append(df_temp, ignore_index=True)
# ...

# %%
df_append_standing["label"] = "standing"
df_append_standing
# Out:
#       # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                   0      46.50       0.50      11.50       0.50      20.33
# 1                 250      46.50       0.50      12.00       0.00      20.25
# 2                 500      46.50       0.50      12.00       0.00      20.50
# 3                 750      46.50       0.50      12.75       0.43      19.50
# 4                1000      46.50       0.50      13.25       0.43      18.75
# ...               ...        ...        ...        ...        ...        ...
# 7195           118750      44.50       0.50      18.75       0.83       5.25
# 7196           119000      44.50       0.50      19.33       0.47       6.00
# 7197           119250      44.50       0.50      19.25       0.83       7.25
# 7198           119500      44.50       0.50      19.00       0.71       8.00
# 7199           119750      44.67       0.47      18.00       0.00       9.00
#
#       var_rss23     label
# ...

# %%
import pandas as pd
import os
import glob

# merging the files
joined_files = os.path.join(r"C:\Users\sarfaraz\Downloads\AReM\sitting", "dataset*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)

df_append_sitting = pd.DataFrame()
#append all files together
for file in joined_list:
            df_temp = pd.read_csv(file, skiprows=4)
            df_append_sitting = df_append_sitting.append(df_temp, ignore_index=True)
df_append_sitting

df_append_sitting["label"] = "sitting"
df_append_sitting
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\632170400.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_sitting = df_append_sitting.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\632170400.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_sitting = df_append_sitting.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\632170400.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_sitting = df_append_sitting.append(df_temp, ignore_index=True)
# ...

# %%
import pandas as pd
import os
import glob

# merging the files
joined_files = os.path.join(r"C:\Users\sarfaraz\Downloads\AReM\lying", "dataset*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)

df_append_lying = pd.DataFrame()
#append all files together
for file in joined_list:
            df_temp = pd.read_csv(file, skiprows=4)
            df_append_lying = df_append_lying.append(df_temp, ignore_index=True)
df_append_lying

# Adding an extra column
df_append_lying["label"] = "lying"
df_append_lying
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\3769996735.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_lying = df_append_lying.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\3769996735.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_lying = df_append_lying.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\3769996735.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_lying = df_append_lying.append(df_temp, ignore_index=True)
# ...

# %%
import pandas as pd
import os
import glob

# merging the files
joined_files = os.path.join(r"C:\Users\sarfaraz\Downloads\AReM\cycling", "dataset*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)

df_append_cycling = pd.DataFrame()
#append all files together
for file in joined_list:
            df_temp = pd.read_csv(file, skiprows=4)
            df_append_cycling = df_append_cycling.append(df_temp, ignore_index=True)
df_append_cycling

# Adding an extra column
df_append_cycling["label"] = "cycling"
df_append_cycling
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\1465311979.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_cycling = df_append_cycling.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\1465311979.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_cycling = df_append_cycling.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\1465311979.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_cycling = df_append_cycling.append(df_temp, ignore_index=True)
# ...

# %%
import pandas as pd
import os
import glob

# merging the files
joined_files = os.path.join(r"C:\Users\sarfaraz\Downloads\AReM\bending2", "dataset*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)

df_append_bending2 = pd.DataFrame()
#append all files together
for file in joined_list:
            df_temp = pd.read_csv(file, skiprows=4)
            df_append_bending2 = df_append_bending2.append(df_temp, ignore_index=True)
df_append_bending2

# Adding an extra column
df_append_bending2["label"] = "bending2"
df_append_bending2
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\3426427248.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_bending2 = df_append_bending2.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\3426427248.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_bending2 = df_append_bending2.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\3426427248.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_bending2 = df_append_bending2.append(df_temp, ignore_index=True)
# ...

# %%
import pandas as pd
import os
import glob

# merging the files
joined_files = os.path.join(r"C:\Users\sarfaraz\Downloads\AReM\bending1", "dataset*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)

df_append_bending1 = pd.DataFrame()
#append all files together
for file in joined_list:
            df_temp = pd.read_csv(file, skiprows=4)
            df_append_bending1 = df_append_bending1.append(df_temp, ignore_index=True)
df_append_bending1

# Adding an extra column
df_append_bending1["label"] = "bending1"
df_append_bending1
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\2690940391.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_bending1 = df_append_bending1.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\2690940391.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_bending1 = df_append_bending1.append(df_temp, ignore_index=True)
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\2690940391.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_bending1 = df_append_bending1.append(df_temp, ignore_index=True)
# ...

# %%
df_merge_all = df_append_walking.append([df_append_standing,df_append_sitting,df_append_lying,df_append_bending1,df_append_bending2])
# Out:
# C:\Users\sarfaraz\AppData\Local\Temp\ipykernel_9464\3586764505.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_merge_all = df_append_walking.append([df_append_standing,df_append_sitting,df_append_lying,df_append_bending1,df_append_bending2])

# %%
df_merge_all
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      35.00       3.67      16.50       3.77      14.00
# 1                250      28.50       3.35      17.50       3.77      12.25
# 2                500      35.50       2.87      15.75       2.86      17.75
# 3                750      29.75      12.19      16.25       2.17      20.75
# 4               1000      27.00       2.12      16.75       0.83      24.75
# ...              ...        ...        ...        ...        ...        ...
# 2875          118750      27.00       0.00      14.00       0.00       6.50
# 2876          119000      27.00       0.00      15.00       0.00       4.00
# 2877          119250      27.00       0.00      14.25       0.83       4.00
# 2878          119500      27.00       0.00      13.33       1.25       1.50
# 2879          119750      26.50       0.50      15.00       0.00       3.00
#
#       var_rss23     label
# 0          1.63   walking
# ...

# %%
set(df_merge_all["label"])
# Out:
# {'bending1', 'bending2', 'lying', 'sitting', 'standing', 'walking'}

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'dataset1.csv',
#  'dataset10.csv',
#  'dataset11.csv',
#  'dataset12.csv',
#  'dataset13.csv',
#  'dataset14.csv',
#  'dataset15.csv',
#  'dataset2.csv',
#  'dataset3.csv',
#  'dataset4.csv',
#  'dataset5.csv',
#  'dataset6.csv',
#  'dataset7.csv',
#  'dataset8.csv',
#  'dataset9.csv']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sarfaraz\\Downloads\\AReM\\walking'

# %%
os.chdir(r"C:\Users\sarfaraz\Downloads\AReM")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sarfaraz\\Downloads\\AReM'

# %%
df_merge_all.to_csv("merged_file.csv")
